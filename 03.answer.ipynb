# %% [markdown]
# # 実験3-3
#
# 1. ImageNet1k で学習済みの ResNet18 モデルに対して，上記と同様の特徴の分布の分析を行い，どの層がどのような表現を与えているかを考察しなさい．
# 2. さらに STL10 で ResNet18 にファインチューニングを施し，上記の表現がどのように変化するかを考察しなさい．
# 3. 上記1, 2 に対して，何種類かの類似画像検索を行い，ファインチューニングの際に，どのような変化が起きているかを考察しなさい．

# %% [markdown]
# ## 以下回答
#
# 回答の実験コードと結果を下記に記述していってください．

# %%
# 1. ImageNet1k で学習済みの ResNet18 モデルに対して，上記と同様の特徴の分布の分析を行い，どの層がどのような表現を与えているかを考察しなさい．

# %%
# 2. さらに STL10 で ResNet18 にファインチューニングを施し，上記の表現がどのように変化するかを考察しなさい．

# %%
# 3. 上記1, 2 に対して，何種類かの類似画像検索を行い，ファインチューニングの際に，どのような変化が起きているかを考察しなさい．
